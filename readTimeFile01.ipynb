# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
timeFile = '/Volumes/Samsung_T5/Felix/biteData_sam/albopictus/190607_01/01/time_03.out'
t = np.loadtxt(timeFile)

# %%
plt.plot(np.diff(t))

# %%
dt = np.diff(t)
1 / dt.mean()
# Out:
# 9.154894394747057
